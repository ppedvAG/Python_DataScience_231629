# %% [markdown]
# ## Pandas
#
# Mit Pandas können wir Daten anaylsieren, die in Tabellarischer Form vorzufinden sind
#
# Formate: XML, JSON, CSV, SQL, ...
#
# Danach können diese Daten visualisiert werden (mithilfe von Matplotlib, ...)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Serie
#
# Eine Serie ist eine Liste von Werten
#
# Eine Serie kann auch noch extra beschrieben werden im Gegensatz zu einem normalen Numpy Array
#
# Bei einer Serie können Numpy Funktion verwendet werden, da ein Numpy Array darunter liegt

# %%
einwohnerM = pd.Series([9, 83.7, 8.6, 0.38])

# %%
einwohnerM
# Out:
# 0     9.00
# 1    83.70
# 2     8.60
# 3     0.38
# dtype: float64

# %%
einwohnerM.sum()
# Out:
# 101.67999999999999

# %%
einwohnerM.mean()
# Out:
# 25.419999999999998

# %%
einwohnerM[0]
# Out:
# 9.0

# %%
einwohnerM.size
# Out:
# 4

# %% [markdown]
# Eine Serie kann noch mit extra Attributen versehen werden

# %%
einwohnerM.name = "Einwohnerzahlen Europa"

# %%
einwohnerM
# Out:
# 0     9.00
# 1    83.70
# 2     8.60
# 3     0.38
# Name: Einwohnerzahlen Europa, dtype: float64

# %%
einwohnerM.values
# Out:
# array([ 9.  , 83.7 ,  8.6 ,  0.38])

# %%
type(einwohnerM.values)
# Out:
# numpy.ndarray

# %%
einwohnerM.index = [
    "AT",
    "DE",
    "CH",
    "LI"
]

# %%
einwohnerM
# Out:
# AT     9.00
# DE    83.70
# CH     8.60
# LI     0.38
# Name: Einwohnerzahlen Europa, dtype: float64

# %%
einwohnerM["AT"]
# Out:
# 9.0

# %%
einwohnerM[0]
# Out:
# C:\Users\lk3\AppData\Local\Temp\ipykernel_10692\3060421205.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   einwohnerM[0]
# 9.0

# %% [markdown]
# ## Sortierung
#
# Es kann nach Werten oder nach dem Index sortiert werden
#
# Hier kann auch die Richtung konfiguriert werden sowie ob die Sortierung auf die Serie angewandt werden soll

# %%
einwohnerM.sort_values(ascending=False)
# Out:
# DE    83.70
# AT     9.00
# CH     8.60
# LI     0.38
# Name: Einwohnerzahlen Europa, dtype: float64

# %%
einwohnerM.sort_index(inplace=True)  # inplace: Funktion anwenden

# %%
einwohnerM
# Out:
# AT     9.00
# CH     8.60
# DE    83.70
# LI     0.38
# Name: Einwohnerzahlen Europa, dtype: float64

# %% [markdown]
# Serie aus einem Dictionary erstellen

# %%
pd.Series({"DE": 83.7, "AT": 9, "CH": 8.6, "LI": 0.38}, dtype=np.float32, name="Einwohnerzahlen Europa")
# Out:
# DE    83.699997
# AT     9.000000
# CH     8.600000
# LI     0.380000
# Name: Einwohnerzahlen Europa, dtype: float32

# %%
einwohnerM["AT":"CH"]  # Textbasierter Index mittels Bereich auswählen (Obergrenze inkludiert)
# Out:
# AT    9.0
# CH    8.6
# Name: Einwohnerzahlen Europa, dtype: float64

# %%
einwohnerM[0:1]  # Hier ist CH nicht dabei
# Out:
# AT    9.0
# Name: Einwohnerzahlen Europa, dtype: float64

# %% [markdown]
# ## Vektorisierung

# %%
einwohnerM > 5
# Out:
# AT     True
# CH     True
# DE     True
# LI    False
# Name: Einwohnerzahlen Europa, dtype: bool

# %%
einwohnerM[einwohnerM > 5]
# Out:
# AT     9.0
# CH     8.6
# DE    83.7
# Name: Einwohnerzahlen Europa, dtype: float64

# %%
einwohnerM.mean()
# Out:
# 25.42

# %%
einwohnerM[(einwohnerM < einwohnerM.mean()) & (einwohnerM > 5)]
# Out:
# AT    9.0
# CH    8.6
# Name: Einwohnerzahlen Europa, dtype: float64

# %% [markdown]
# ## DataFrame
#
# Effektiv eine Tabelle (CSV, SQL), Zweidimensional
#
# Hier ist es sinnvoll eine Tabelle zu laden

# %%
pd.DataFrame({"Spalte1": [1, 2, 3], "Spalte2": [4, 5,6], "Spalte3": [7, 8, 9]})
# Out:
#    Spalte1  Spalte2  Spalte3
# 0        1        4        7
# 1        2        5        8
# 2        3        6        9

# %% [markdown]
# Es gibt verschiedene Möglichkeiten um Daten einzulesen
#
# Wir fangen mit read_csv an

# %%
df = pd.read_csv("Data/PopulationData.csv", delimiter=";", decimal=".", thousands=",")  # index_col="Country (or dependency)"

# %%
df
# Out:
#        # Country (or dependency)  Population(2020) YearlyChange  NetChange  \
# 0      1                   China        1439323776       0.39 %    5540090
# 1      2                   India        1380004385       0.99 %   13586631
# 2      3           United States         331002651       0.59 %    1937734
# 3      4               Indonesia         273523615       1.07 %    2898047
# 4      5                Pakistan         220892340       2.00 %    4327022
# ..   ...                     ...               ...          ...        ...
# 230  231              Montserrat              4992       0.06 %          3
# 231  232        Falkland Islands              3480       3.05 %        103
# 232  233                    Niue              1626       0.68 %         11
# 233  234                 Tokelau              1357       1.27 %         17
# 234  235           Vatican State               801       0.25 %          2
#
#      Density(P/Km²)  Land Area(Km²)  Migrants(net) Fert.Rate Med.Age  \
# 0               153         9388211      -348399.0       1.7      38
# 1               464         2973190      -532687.0       2.2      28
# 2                36         9147420       954806.0       1.8      38
# 3               151         1811570       -98955.0       2.3      30
# 4               287          770880      -233379.0       3.6      23
# ..              ...             ...            ...       ...     ...
# 230              50             100            NaN      N.A.    N.A.
# 231               0           12170            NaN      N.A.    N.A.
# 232               6             260            NaN      N.A.    N.A.
# 233             136              10            NaN      N.A.    N.A.
# 234            2003               0            NaN      N.A.    N.A.
#
#     UrbanPop % WorldShare
# 0         61 %    18.47 %
# 1         35 %    17.70 %
# 2         83 %     4.25 %
# 3         56 %     3.51 %
# 4         35 %     2.83 %
# ..         ...        ...
# 230       10 %     0.00 %
# 231       66 %     0.00 %
# 232       46 %     0.00 %
# 233        0 %     0.00 %
# 234       N.A.     0.00 %
#
# [235 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   #                        235 non-null    int64
#  1   Country (or dependency)  235 non-null    object
#  2   Population(2020)         235 non-null    int64
#  3   YearlyChange             235 non-null    object
#  4   NetChange                235 non-null    int64
#  5   Density(P/Km²)           235 non-null    int64
#  6   Land Area(Km²)           235 non-null    int64
#  7   Migrants(net)            201 non-null    float64
#  8   Fert.Rate                235 non-null    object
#  9   Med.Age                  235 non-null    object
#  10  UrbanPop %               235 non-null    object
#  11  WorldShare               235 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 22.2+ KB

# %%
df.head()  # Gibt die obersten X (standardmäßig 5) Datensätze aus
# Out:
#    # Country (or dependency)  Population(2020) YearlyChange  NetChange  \
# 0  1                   China        1439323776       0.39 %    5540090
# 1  2                   India        1380004385       0.99 %   13586631
# 2  3           United States         331002651       0.59 %    1937734
# 3  4               Indonesia         273523615       1.07 %    2898047
# 4  5                Pakistan         220892340       2.00 %    4327022
#
#    Density(P/Km²)  Land Area(Km²)  Migrants(net) Fert.Rate Med.Age UrbanPop %  \
# 0             153         9388211      -348399.0       1.7      38       61 %
# 1             464         2973190      -532687.0       2.2      28       35 %
# 2              36         9147420       954806.0       1.8      38       83 %
# 3             151         1811570       -98955.0       2.3      30       56 %
# 4             287          770880      -233379.0       3.6      23       35 %
#
#   WorldShare
# 0    18.47 %
# 1    17.70 %
# 2     4.25 %
# 3     3.51 %
# 4     2.83 %

# %%
df.tail()  # Ermöglicht, mehr als 5 Zeilen auszugeben im Gegensatz zu der DataFrame Variable
# Out:
#        # Country (or dependency)  Population(2020) YearlyChange  NetChange  \
# 230  231              Montserrat              4992       0.06 %          3
# 231  232        Falkland Islands              3480       3.05 %        103
# 232  233                    Niue              1626       0.68 %         11
# 233  234                 Tokelau              1357       1.27 %         17
# 234  235           Vatican State               801       0.25 %          2
#
#      Density(P/Km²)  Land Area(Km²)  Migrants(net) Fert.Rate Med.Age  \
# 230              50             100            NaN      N.A.    N.A.
# 231               0           12170            NaN      N.A.    N.A.
# 232               6             260            NaN      N.A.    N.A.
# 233             136              10            NaN      N.A.    N.A.
# 234            2003               0            NaN      N.A.    N.A.
#
#     UrbanPop % WorldShare
# 230       10 %     0.00 %
# 231       66 %     0.00 %
# 232       46 %     0.00 %
# 233        0 %     0.00 %
# 234       N.A.     0.00 %

# %%
df.describe()
# Out:
#                 #  Population(2020)     NetChange  Density(P/Km²)  \
# count  235.000000      2.350000e+02  2.350000e+02      235.000000
# mean   118.000000      3.317120e+07  3.461058e+05      478.408511
# std     67.982841      1.351370e+08  1.128255e+06     2331.282424
# min      1.000000      8.010000e+02 -3.838400e+05        0.000000
# 25%     59.500000      4.188015e+05  4.240000e+02       37.000000
# 50%    118.000000      5.459642e+06  3.917000e+04       95.000000
# 75%    176.500000      2.057705e+07  2.496600e+05      240.000000
# max    235.000000      1.439324e+09  1.358663e+07    26337.000000
#
#        Land Area(Km²)  Migrants(net)
# count    2.350000e+02     201.000000
# mean     5.535918e+05      -5.442786
# std      1.687796e+06  123292.057588
# min      0.000000e+00 -653249.000000
# 25%      2.545000e+03  -10047.000000
# 50%      7.724000e+04    -960.000000
# 75%      4.038200e+05    9741.000000
# max      1.637687e+07  954806.000000

# %% [markdown]
# ## Einzelne Spalten/Zeilen angreifen

# %%
df["Population(2020)"]
# Out:
# 0      1439323776
# 1      1380004385
# 2       331002651
# 3       273523615
# 4       220892340
#           ...
# 230          4992
# 231          3480
# 232          1626
# 233          1357
# 234           801
# Name: Population(2020), Length: 235, dtype: int64

# %%
df.loc[0]  # loc wird verwendet um Zeilen anzugreifen
# Out:
# #                                   1
# Country (or dependency)         China
# Population(2020)           1439323776
# YearlyChange                   0.39 %
# NetChange                     5540090
# Density(P/Km²)                    153
# Land Area(Km²)                9388211
# Migrants(net)               -348399.0
# Fert.Rate                         1.7
# Med.Age                            38
# UrbanPop %                       61 %
# WorldShare                    18.47 %
# Name: 0, dtype: object

# %%
df.loc[5:10]
# Out:
#      # Country (or dependency)  Population(2020) YearlyChange  NetChange  \
# 5    6                  Brazil         212559417       0.72 %    1509890
# 6    7                 Nigeria         206139589       2.58 %    5175990
# 7    8              Bangladesh         164689383       1.01 %    1643222
# 8    9                  Russia         145934462       0.04 %      62206
# 9   10                  Mexico         128932753       1.06 %    1357224
# 10  11                   Japan         126476461      -0.30 %    -383840
#
#     Density(P/Km²)  Land Area(Km²)  Migrants(net) Fert.Rate Med.Age  \
# 5               25         8358140        21200.0       1.7      33
# 6              226          910770       -60000.0       5.4      18
# 7             1265          130170      -369501.0       2.1      28
# 8                9        16376870       182456.0       1.8      40
# 9               66         1943950       -60000.0       2.1      29
# 10             347          364555        71560.0       1.4      48
#
#    UrbanPop % WorldShare
# 5        88 %     2.73 %
# 6        52 %     2.64 %
# 7        39 %     2.11 %
# 8        74 %     1.87 %
# 9        84 %     1.65 %
# 10       92 %     1.62 %

# %%
df.loc[5:10, ["Country (or dependency)", "Population(2020)"]]
# Out:
#    Country (or dependency)  Population(2020)
# 5                   Brazil         212559417
# 6                  Nigeria         206139589
# 7               Bangladesh         164689383
# 8                   Russia         145934462
# 9                   Mexico         128932753
# 10                   Japan         126476461

# %% [markdown]
# ## Daten filtern mithilfe von Vektorisierung

# %%
df["Land Area(Km²)"] > 5_000_000
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# Name: Land Area(Km²), Length: 235, dtype: bool

# %%
df[df["Land Area(Km²)"] > 5_000_000]
# Out:
#      # Country (or dependency)  Population(2020) YearlyChange  NetChange  \
# 0    1                   China        1439323776       0.39 %    5540090
# 2    3           United States         331002651       0.59 %    1937734
# 5    6                  Brazil         212559417       0.72 %    1509890
# 8    9                  Russia         145934462       0.04 %      62206
# 38  39                  Canada          37742154       0.89 %     331107
# 54  55               Australia          25499884       1.18 %     296686
#
#     Density(P/Km²)  Land Area(Km²)  Migrants(net) Fert.Rate Med.Age  \
# 0              153         9388211      -348399.0       1.7      38
# 2               36         9147420       954806.0       1.8      38
# 5               25         8358140        21200.0       1.7      33
# 8                9        16376870       182456.0       1.8      40
# 38               4         9093510       242032.0       1.5      41
# 54               3         7682300       158246.0       1.8      38
#
#    UrbanPop % WorldShare
# 0        61 %    18.47 %
# 2        83 %     4.25 %
# 5        88 %     2.73 %
# 8        74 %     1.87 %
# 38       81 %     0.48 %
# 54       86 %     0.33 %

# %%
df = df[df["Land Area(Km²)"] > 5_000_000]
# Out:
#        # Country (or dependency)  Population(2020) YearlyChange  NetChange  \
# 0      1                   China        1439323776       0.39 %    5540090
# 1      2                   India        1380004385       0.99 %   13586631
# 2      3           United States         331002651       0.59 %    1937734
# 3      4               Indonesia         273523615       1.07 %    2898047
# 4      5                Pakistan         220892340       2.00 %    4327022
# ..   ...                     ...               ...          ...        ...
# 230  231              Montserrat              4992       0.06 %          3
# 231  232        Falkland Islands              3480       3.05 %        103
# 232  233                    Niue              1626       0.68 %         11
# 233  234                 Tokelau              1357       1.27 %         17
# 234  235           Vatican State               801       0.25 %          2
#
#      Density(P/Km²)  Land Area(Km²)  Migrants(net) Fert.Rate Med.Age  \
# 0               153         9388211      -348399.0       1.7      38
# 1               464         2973190      -532687.0       2.2      28
# 2                36         9147420       954806.0       1.8      38
# 3               151         1811570       -98955.0       2.3      30
# 4               287          770880      -233379.0       3.6      23
# ..              ...             ...            ...       ...     ...
# 230              50             100            NaN      N.A.    N.A.
# 231               0           12170            NaN      N.A.    N.A.
# 232               6             260            NaN      N.A.    N.A.
# 233             136              10            NaN      N.A.    N.A.
# 234            2003               0            NaN      N.A.    N.A.
#
#     UrbanPop % WorldShare
# 0         61 %    18.47 %
# 1         35 %    17.70 %
# 2         83 %     4.25 %
# 3         56 %     3.51 %
# 4         35 %     2.83 %
# ..         ...        ...
# 230       10 %     0.00 %
# 231       66 %     0.00 %
# 232       46 %     0.00 %
# 233        0 %     0.00 %
# 234       N.A.     0.00 %
#
# [235 rows x 12 columns]

# %% [markdown]
# ## Sortierung
#
# Ergebnisse mit der sort_values Funktion sortieren
#
# Parameter:
# 1. Die Spalte nach der sortiert wird
# 2. ascending=True/False
# 3. inplace=True/False -> Sortierung wird auf das Datenset angewandt

# %%
df.sort_values("Land Area(Km²)", ascending=False, inplace=True)

# %%
df
# Out:
#        # Country (or dependency)  Population(2020) YearlyChange  NetChange  \
# 0      1                   China        1439323776       0.39 %    5540090
# 1      2                   India        1380004385       0.99 %   13586631
# 2      3           United States         331002651       0.59 %    1937734
# 3      4               Indonesia         273523615       1.07 %    2898047
# 4      5                Pakistan         220892340       2.00 %    4327022
# ..   ...                     ...               ...          ...        ...
# 230  231              Montserrat              4992       0.06 %          3
# 231  232        Falkland Islands              3480       3.05 %        103
# 232  233                    Niue              1626       0.68 %         11
# 233  234                 Tokelau              1357       1.27 %         17
# 234  235           Vatican State               801       0.25 %          2
#
#      Density(P/Km²)  Land Area(Km²)  Migrants(net) Fert.Rate Med.Age  \
# 0               153         9388211      -348399.0       1.7      38
# 1               464         2973190      -532687.0       2.2      28
# 2                36         9147420       954806.0       1.8      38
# 3               151         1811570       -98955.0       2.3      30
# 4               287          770880      -233379.0       3.6      23
# ..              ...             ...            ...       ...     ...
# 230              50             100            NaN      N.A.    N.A.
# 231               0           12170            NaN      N.A.    N.A.
# 232               6             260            NaN      N.A.    N.A.
# 233             136              10            NaN      N.A.    N.A.
# 234            2003               0            NaN      N.A.    N.A.
#
#     UrbanPop % WorldShare
# 0         61 %    18.47 %
# 1         35 %    17.70 %
# 2         83 %     4.25 %
# 3         56 %     3.51 %
# 4         35 %     2.83 %
# ..         ...        ...
# 230       10 %     0.00 %
# 231       66 %     0.00 %
# 232       46 %     0.00 %
# 233        0 %     0.00 %
# 234       N.A.     0.00 %
#
# [235 rows x 12 columns]

# %%
df[df["Land Area(Km²)"] > 1_000_000].sort_values("Land Area(Km²)", ascending=False)
# Out:
#        # Country (or dependency)  Population(2020) YearlyChange  NetChange  \
# 8      9                  Russia         145934462       0.04 %      62206
# 0      1                   China        1439323776       0.39 %    5540090
# 2      3           United States         331002651       0.59 %    1937734
# 38    39                  Canada          37742154       0.89 %     331107
# 5      6                  Brazil         212559417       0.72 %    1509890
# 54    55               Australia          25499884       1.18 %     296686
# 1      2                   India        1380004385       0.99 %   13586631
# 31    32               Argentina          45195774       0.93 %     415097
# 63    64              Kazakhstan          18776707       1.21 %     225280
# 32    33                 Algeria          43851044       1.85 %     797990
# 15    16                DR Congo          89561403       3.19 %    2770836
# 40    41            Saudi Arabia          34813871       1.59 %     545343
# 9     10                  Mexico         128932753       1.06 %    1357224
# 3      4               Indonesia         273523615       1.07 %    2898047
# 33    34                   Sudan          43849260       2.42 %    1036022
# 107  108                   Libya           6871292       1.38 %      93840
# 17    18                    Iran          83992949       1.30 %    1079043
# 135  136                Mongolia           3278290       1.65 %      53123
# 42    43                    Peru          32971854       1.42 %     461401
# 55    56                   Niger          24206644       3.84 %     895929
# 71    72                    Chad          16425864       3.00 %     478988
# 43    44                  Angola          32866272       3.27 %    1040977
# 59    60                    Mali          20250833       3.02 %     592802
# 24    25            South Africa          59308690       1.28 %     750420
# 28    29                Colombia          50882891       1.08 %     543448
# 79    80                 Bolivia          11673021       1.39 %     159921
# 126  127              Mauritania           4649658       2.74 %     123962
#
#      Density(P/Km²)  Land Area(Km²)  Migrants(net) Fert.Rate Med.Age  \
# 8                 9        16376870       182456.0       1.8      40
# 0               153         9388211      -348399.0       1.7      38
# 2                36         9147420       954806.0       1.8      38
# 38                4         9093510       242032.0       1.5      41
# 5                25         8358140        21200.0       1.7      33
# 54                3         7682300       158246.0       1.8      38
# 1               464         2973190      -532687.0       2.2      28
# 31               17         2736690         4800.0       2.3      32
# 63                7         2699700       -18000.0       2.8      31
# 32               18         2381740       -10000.0       3.1      29
# 15               40         2267050        23861.0       6.0      17
# 40               16         2149690       134979.0       2.3      32
# 9                66         1943950       -60000.0       2.1      29
# 3               151         1811570       -98955.0       2.3      30
# 33               25         1765048       -50000.0       4.4      20
# 107               4         1759540        -1999.0       2.3      29
# 17               52         1628550       -55000.0       2.2      32
# 135               2         1553560         -852.0       2.9      28
# 42               26         1280000        99069.0       2.3      31
# 55               19         1266700         4000.0       7.0      15
# 71               13         1259200         2000.0       5.8      17
# 43               26         1246700         6413.0       5.6      17
# 59               17         1220190       -40000.0       5.9      16
# 24               49         1213090       145405.0       2.4      28
# 28               46         1109500       204796.0       1.8      31
# 79               11         1083300        -9504.0       2.8      26
# 126               5         1030700         5000.0       4.6      20
#
#     UrbanPop % WorldShare
# 8         74 %     1.87 %
# 0         61 %    18.47 %
# 2         83 %     4.25 %
# 38        81 %     0.48 %
# 5         88 %     2.73 %
# 54        86 %     0.33 %
# 1         35 %    17.70 %
# 31        93 %     0.58 %
# 63        58 %     0.24 %
# 32        73 %     0.56 %
# 15        46 %     1.15 %
# 40        84 %     0.45 %
# 9         84 %     1.65 %
# 3         56 %     3.51 %
# 33        35 %     0.56 %
# 107       78 %     0.09 %
# 17        76 %     1.08 %
# 135       67 %     0.04 %
# 42        79 %     0.42 %
# 55        17 %     0.31 %
# 71        23 %     0.21 %
# 43        67 %     0.42 %
# 59        44 %     0.26 %
# 24        67 %     0.76 %
# 28        80 %     0.65 %
# 79        69 %     0.15 %
# 126       57 %     0.06 %

# %% [markdown]
# ## Spalten entfernen
#
# Spalten die nicht nützlich sind können entfernt werden
#
# WICHTIG: Hier kommt ein neues DataFrame heraus, Ergebnis zuweisen um die Änderung zu übernehmen

# %%
df.drop(columns=["Density(P/Km²)", "#"], inplace=True)

# %%
df
# Out:
#     Country (or dependency)  Population(2020) YearlyChange  NetChange  \
# 0                     China        1439323776       0.39 %    5540090
# 1                     India        1380004385       0.99 %   13586631
# 2             United States         331002651       0.59 %    1937734
# 3                 Indonesia         273523615       1.07 %    2898047
# 4                  Pakistan         220892340       2.00 %    4327022
# ..                      ...               ...          ...        ...
# 230              Montserrat              4992       0.06 %          3
# 231        Falkland Islands              3480       3.05 %        103
# 232                    Niue              1626       0.68 %         11
# 233                 Tokelau              1357       1.27 %         17
# 234           Vatican State               801       0.25 %          2
#
#      Land Area(Km²)  Migrants(net) Fert.Rate Med.Age UrbanPop % WorldShare
# 0           9388211      -348399.0       1.7      38       61 %    18.47 %
# 1           2973190      -532687.0       2.2      28       35 %    17.70 %
# 2           9147420       954806.0       1.8      38       83 %     4.25 %
# 3           1811570       -98955.0       2.3      30       56 %     3.51 %
# 4            770880      -233379.0       3.6      23       35 %     2.83 %
# ..              ...            ...       ...     ...        ...        ...
# 230             100            NaN      N.A.    N.A.       10 %     0.00 %
# 231           12170            NaN      N.A.    N.A.       66 %     0.00 %
# 232             260            NaN      N.A.    N.A.       46 %     0.00 %
# 233              10            NaN      N.A.    N.A.        0 %     0.00 %
# 234               0            NaN      N.A.    N.A.       N.A.     0.00 %
#
# [235 rows x 10 columns]

# %%
df.drop(df.index[20:])  # Zeilen entfernen mithilfe eines RangeIndex Objekts
# Out:
#    Country (or dependency)  Population(2020) YearlyChange  NetChange  \
# 0                    China        1439323776       0.39 %    5540090
# 1                    India        1380004385       0.99 %   13586631
# 2            United States         331002651       0.59 %    1937734
# 3                Indonesia         273523615       1.07 %    2898047
# 4                 Pakistan         220892340       2.00 %    4327022
# 5                   Brazil         212559417       0.72 %    1509890
# 6                  Nigeria         206139589       2.58 %    5175990
# 7               Bangladesh         164689383       1.01 %    1643222
# 8                   Russia         145934462       0.04 %      62206
# 9                   Mexico         128932753       1.06 %    1357224
# 10                   Japan         126476461      -0.30 %    -383840
# 11                Ethiopia         114963588       2.57 %    2884858
# 12             Philippines         109581078       1.35 %    1464463
# 13                   Egypt         102334404       1.94 %    1946331
# 14                 Vietnam          97338579       0.91 %     876473
# 15                DR Congo          89561403       3.19 %    2770836
# 16                  Turkey          84339067       1.09 %     909452
# 17                    Iran          83992949       1.30 %    1079043
# 18                 Germany          83783942       0.32 %     266897
# 19                Thailand          69799978       0.25 %     174396
#
#     Land Area(Km²)  Migrants(net) Fert.Rate Med.Age UrbanPop % WorldShare
# 0          9388211      -348399.0       1.7      38       61 %    18.47 %
# 1          2973190      -532687.0       2.2      28       35 %    17.70 %
# 2          9147420       954806.0       1.8      38       83 %     4.25 %
# 3          1811570       -98955.0       2.3      30       56 %     3.51 %
# 4           770880      -233379.0       3.6      23       35 %     2.83 %
# 5          8358140        21200.0       1.7      33       88 %     2.73 %
# 6           910770       -60000.0       5.4      18       52 %     2.64 %
# 7           130170      -369501.0       2.1      28       39 %     2.11 %
# 8         16376870       182456.0       1.8      40       74 %     1.87 %
# 9          1943950       -60000.0       2.1      29       84 %     1.65 %
# 10          364555        71560.0       1.4      48       92 %     1.62 %
# 11         1000000        30000.0       4.3      19       21 %     1.47 %
# 12          298170       -67152.0       2.6      26       47 %     1.41 %
# 13          995450       -38033.0       3.3      25       43 %     1.31 %
# 14          310070       -80000.0       2.1      32       38 %     1.25 %
# 15         2267050        23861.0       6.0      17       46 %     1.15 %
# 16          769630       283922.0       2.1      32       76 %     1.08 %
# 17         1628550       -55000.0       2.2      32       76 %     1.08 %
# 18          348560       543822.0       1.6      46       76 %     1.07 %
# 19          510890        19444.0       1.5      40       51 %     0.90 %

# %% [markdown]
# ## Spalten umbenennen
#
# Zum Umbenennen von Spalten gibt es die rename() Funktion. Diese Funktion benötigt ein Dictionary als Parameter, welches die bestehenden Spaltennamen als Schlüssel und die neuen Spaltennamen als zugehörige Values enthält
#
# WICHTIG: Hier kommt ein neues DataFrame heraus, Ergebnis zuweisen um die Änderung zu übernehmen

# %%
df.rename(columns={"Country (or dependency)": "Country", "Population(2020)": "Pop", "Land Area(Km²)": "Land Area"}, inplace=True)

# %%
df
# Out:
#               Country         Pop YearlyChange  NetChange  Land Area  \
# 0               China  1439323776       0.39 %    5540090    9388211
# 1               India  1380004385       0.99 %   13586631    2973190
# 2       United States   331002651       0.59 %    1937734    9147420
# 3           Indonesia   273523615       1.07 %    2898047    1811570
# 4            Pakistan   220892340       2.00 %    4327022     770880
# ..                ...         ...          ...        ...        ...
# 230        Montserrat        4992       0.06 %          3        100
# 231  Falkland Islands        3480       3.05 %        103      12170
# 232              Niue        1626       0.68 %         11        260
# 233           Tokelau        1357       1.27 %         17         10
# 234     Vatican State         801       0.25 %          2          0
#
#      Migrants(net) Fert.Rate Med.Age UrbanPop % WorldShare
# 0        -348399.0       1.7      38       61 %    18.47 %
# 1        -532687.0       2.2      28       35 %    17.70 %
# 2         954806.0       1.8      38       83 %     4.25 %
# 3         -98955.0       2.3      30       56 %     3.51 %
# 4        -233379.0       3.6      23       35 %     2.83 %
# ..             ...       ...     ...        ...        ...
# 230            NaN      N.A.    N.A.       10 %     0.00 %
# 231            NaN      N.A.    N.A.       66 %     0.00 %
# 232            NaN      N.A.    N.A.       46 %     0.00 %
# 233            NaN      N.A.    N.A.        0 %     0.00 %
# 234            NaN      N.A.    N.A.       N.A.     0.00 %
#
# [235 rows x 10 columns]

# %% [markdown]
# ## Neue Spalten hinzufügen

# %%
df["Pop/Area"] = round(df["Pop"] / df["Land Area"], 2)

# %%
df
# Out:
#               Country         Pop YearlyChange  NetChange  Land Area  \
# 0               China  1439323776       0.39 %    5540090    9388211
# 1               India  1380004385       0.99 %   13586631    2973190
# 2       United States   331002651       0.59 %    1937734    9147420
# 3           Indonesia   273523615       1.07 %    2898047    1811570
# 4            Pakistan   220892340       2.00 %    4327022     770880
# ..                ...         ...          ...        ...        ...
# 230        Montserrat        4992       0.06 %          3        100
# 231  Falkland Islands        3480       3.05 %        103      12170
# 232              Niue        1626       0.68 %         11        260
# 233           Tokelau        1357       1.27 %         17         10
# 234     Vatican State         801       0.25 %          2          0
#
#      Migrants(net) Fert.Rate Med.Age UrbanPop % WorldShare  Pop/Area
# 0        -348399.0       1.7      38       61 %    18.47 %    153.31
# 1        -532687.0       2.2      28       35 %    17.70 %    464.15
# 2         954806.0       1.8      38       83 %     4.25 %     36.19
# 3         -98955.0       2.3      30       56 %     3.51 %    150.99
# 4        -233379.0       3.6      23       35 %     2.83 %    286.55
# ..             ...       ...     ...        ...        ...       ...
# 230            NaN      N.A.    N.A.       10 %     0.00 %     49.92
# 231            NaN      N.A.    N.A.       66 %     0.00 %      0.29
# 232            NaN      N.A.    N.A.       46 %     0.00 %      6.25
# 233            NaN      N.A.    N.A.        0 %     0.00 %    135.70
# 234            NaN      N.A.    N.A.       N.A.     0.00 %       inf
#
# [235 rows x 11 columns]

# %% [markdown]
# ## Index setzen
#
# Es kann beim DataFrame eine eigene Spalte als Index gesetzt werden (statt dem Standart Numerischen Index)
#
# Der Index kann auch beim einlesen der Daten direkt gesetzt werden mithilfe von index_col="Spaltenname"

# %%
df.set_index("Country", inplace=True)

# %%
df
# Out:
#                          Pop YearlyChange  NetChange  Land Area  \
# Country
# China             1439323776       0.39 %    5540090    9388211
# India             1380004385       0.99 %   13586631    2973190
# United States      331002651       0.59 %    1937734    9147420
# Indonesia          273523615       1.07 %    2898047    1811570
# Pakistan           220892340       2.00 %    4327022     770880
# ...                      ...          ...        ...        ...
# Montserrat              4992       0.06 %          3        100
# Falkland Islands        3480       3.05 %        103      12170
# Niue                    1626       0.68 %         11        260
# Tokelau                 1357       1.27 %         17         10
# Vatican State            801       0.25 %          2          0
#
#                   Migrants(net) Fert.Rate Med.Age UrbanPop % WorldShare  \
# Country
# China                 -348399.0       1.7      38       61 %    18.47 %
# India                 -532687.0       2.2      28       35 %    17.70 %
# United States          954806.0       1.8      38       83 %     4.25 %
# Indonesia              -98955.0       2.3      30       56 %     3.51 %
# Pakistan              -233379.0       3.6      23       35 %     2.83 %
# ...                         ...       ...     ...        ...        ...
# Montserrat                  NaN      N.A.    N.A.       10 %     0.00 %
# Falkland Islands            NaN      N.A.    N.A.       66 %     0.00 %
# Niue                        NaN      N.A.    N.A.       46 %     0.00 %
# Tokelau                     NaN      N.A.    N.A.        0 %     0.00 %
# Vatican State               NaN      N.A.    N.A.       N.A.     0.00 %
#
#                   Pop/Area
# Country
# China               153.31
# India               464.15
# United States        36.19
# Indonesia           150.99
# Pakistan            286.55
# ...                    ...
# Montserrat           49.92
# Falkland Islands      0.29
# Niue                  6.25
# Tokelau             135.70
# Vatican State          inf
#
# [235 rows x 10 columns]

# %% [markdown]
# ## Gruppierung
#
# Bei der Ermittlung von Werten aus Mengen werden oft Gruppierungen verwendet. Dafür gibt es in Pandas die groupby() Funktion. Diese Funktion erzeugt Gruppen anhand eines Kriteriums (z.B.: Jahreszahlen -> 2011er Gruppe, 2012er Gruppe, 2013er Gruppe, ...)
#
# Aufgaben die mit groupby() zu lösen sind, werden oft mit "pro" angegeben (pro Jahr, pro Land, pro Kunde)
#
# Mit der get_group() Funktion können wir einzelne Gruppen anschauen

# %%
df["Med.Age"].unique()
# Out:
# array(['38', '28', '30', '23', '33', '18', '40', '29', '48', '19', '26',
#        '25', '32', '17', '46', '42', '47', '20', '44', '31', '45', '41',
#        '21', '22', '35', '15', '34', '16', '43', '24', '27', '37', '36',
#        '39', 'N.A.'], dtype=object)

# %%
df.groupby("Med.Age")  # Pro Alter eine Gruppe mit den Datensätzen (15er Gruppe, 17er Gruppe, 19er Gruppe, ...)
df.groupby("Med.Age").get_group("19")
# Out:
#        # Country (or dependency)  Population(2020) YearlyChange  NetChange  \
# 11    12                Ethiopia         114963588       2.57 %    2884858
# 51    52                Cameroon          26545863       2.59 %     669483
# 52    53           Côte d'Ivoire          26378274       2.57 %     661730
# 69    70                 Senegal          16743927       2.75 %     447563
# 73    74                Zimbabwe          14862924       1.48 %     217456
# 76    77                   Benin          12123200       2.73 %     322049
# 83    84             South Sudan          11193725       1.19 %     131612
# 101  102                    Togo           8278724       2.43 %     196358
# 102  103            Sierra Leone           7976983       2.10 %     163768
# 116  117                   Congo           5518087       2.56 %     137579
# 122  123                 Liberia           5057681       2.44 %     120307
# 132  133                 Eritrea           3546421       1.41 %      49304
# 149  150           Guinea-Bissau           1968001       2.45 %      47079
# 187  188     Sao Tome & Principe            219159       1.91 %       4103
#
#      Density(P/Km²)  Land Area(Km²)  Migrants(net) Fert.Rate Med.Age  \
# 11              115         1000000        30000.0       4.3      19
# 51               56          472710        -4800.0       4.6      19
# 52               83          318000        -8000.0       4.7      19
# 69               87          192530       -20000.0       4.7      19
# 73               38          386850      -116858.0       3.6      19
# 76              108          112760        -2000.0       4.9      19
# 83               18          610952      -174200.0       4.7      19
# 101             152           54390        -2000.0       4.4      19
# 102             111           72180        -4200.0       4.3      19
# 116              16          341500        -4000.0       4.5      19
# 122              53           96320        -5000.0       4.4      19
# 132              35          101000       -39858.0       4.1      19
# 149              70           28120        -1399.0       4.5      19
# 187             228             960        -1680.0       4.4      19
#
#     UrbanPop % WorldShare
# 11        21 %     1.47 %
# 51        56 %     0.34 %
# 52        51 %     0.34 %
# 69        49 %     0.21 %
# 73        38 %     0.19 %
# 76        48 %     0.16 %
# 83        25 %     0.14 %
# 101       43 %     0.11 %
# 102       43 %     0.10 %
# 116       70 %     0.07 %
# 122       53 %     0.06 %
# 132       63 %     0.05 %
# 149       45 %     0.03 %
# 187       74 %     0.00 %

# %%
df.groupby("Med.Age").get_group("19")["Population(2020)"].mean()
# Out:
# 18241182.64285714

# %%
df.groupby("Med.Age")["Population(2020)"].mean()
# Out:
# Med.Age
# 15      2.420664e+07
# 16      2.025083e+07
# 17      3.539643e+07
# 18      4.148540e+07
# 19      1.824118e+07
# 20      1.939652e+07
# 21      9.621932e+06
# 22      7.686515e+06
# 23      6.028827e+07
# 24      7.213284e+06
# 25      3.304188e+07
# 26      2.510786e+07
# 27      2.088666e+06
# 28      1.398790e+08
# 29      4.693030e+07
# 30      4.894655e+07
# 31      1.847800e+07
# 32      3.284957e+07
# 33      4.789470e+07
# 34      3.726593e+06
# 35      1.595275e+07
# 36      2.161582e+06
# 37      1.772735e+06
# 38      2.590871e+08
# 39      1.120258e+06
# 40      4.277205e+07
# 41      1.942832e+07
# 42      1.717237e+07
# 43      7.631299e+06
# 44      1.210433e+07
# 45      1.320029e+07
# 46      3.480124e+07
# 47      3.041855e+07
# 48      1.264765e+08
# N.A.    3.333179e+04
# Name: Population(2020), dtype: float64
