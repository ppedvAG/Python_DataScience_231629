# %% [markdown]
# ## Snake Modell

# %%
import gymnasium as gym
import numpy as np
import Snake
from gymnasium.spaces import Discrete, Box
from typing import Optional

# %%
class SnakePlayer(gym.Env):
    def __init__(self):
        self.game = Snake.SnakeGame()
        self.action_space = Discrete(4)
        self.observation_space = Box(0, 100, shape=(self.game.gridSize[0], self.game.gridSize[1]), dtype=int)
        self.state = self.game.grid
        self.lastScore = 0
        
    def step(self, action):
        self.game.nextDirection = action

        self.game.step()

        reward = 0
        if self.game.score > self.lastScore:
            reward = 5
            self.lastScore = self.game.score

        self.state = self.game.grid

        return np.array(self.state), reward, self.game.death, False, {"Steps": self.game.steps, "Score": self.game.score}
    
    def reset(self, *, seed: Optional[int] = None, options: Optional[dict] = None,):
        if hasattr(self.game, "window"):
            try:
                self.game.window.destroy()
            except: pass
        
        self.game = Snake.SnakeGame()
        self.state = self.game.grid
        self.lastScore = 0
        return (np.array(self.state), {})
        
    def render(self):
        self.game.setupUI()
        self.game.window.update()
        pass
        
    def close(self):
        pass

# %%
env = SnakePlayer()

# %%
durchgänge = 5  # Anzahl der Durchgänge
for i in range(durchgänge):  # Teste die Umgebung X mal
    state = env.reset()  # Setze die Umgebung für den nächsten Durchlauf zurück
    done = False  # Brich den Prozess ab, wenn z.B. die Zeit abläuft
    score = 0

    while not done:
        # env.render()  # Zeichne die Umgebung
        action = env.action_space.sample()  # Nimmt ein Random Element aus dem Action Space (Links oder Rechts)
        state, reward, done, term, info = env.step(action)  # state: Observation Space, reward: Belohnung, done: Fertig Ja/Nein, term: Termination (vorzeitiges Beenden), info: Extra Infos
        score += reward
    print(f"Durchgang {i}, Score: {score}, Info: {info}")
env.close()
# Out:
# Durchgang 0, Score: 0, Info: {'Steps': 294, 'Score': 0}
# Durchgang 1, Score: 0, Info: {'Steps': 53, 'Score': 0}
# Durchgang 2, Score: 0, Info: {'Steps': 45, 'Score': 0}
# Durchgang 3, Score: 0, Info: {'Steps': 38, 'Score': 0}
# Durchgang 4, Score: 0, Info: {'Steps': 56, 'Score': 0}
# Durchgang 5, Score: 5, Info: {'Steps': 32, 'Score': 1}
# Durchgang 6, Score: 0, Info: {'Steps': 65, 'Score': 0}
# Durchgang 7, Score: 0, Info: {'Steps': 17, 'Score': 0}
# Durchgang 8, Score: 0, Info: {'Steps': 43, 'Score': 0}
# Durchgang 9, Score: 0, Info: {'Steps': 42, 'Score': 0}
# Durchgang 10, Score: 0, Info: {'Steps': 57, 'Score': 0}
# Durchgang 11, Score: 0, Info: {'Steps': 19, 'Score': 0}
# Durchgang 12, Score: 0, Info: {'Steps': 40, 'Score': 0}
# Durchgang 13, Score: 0, Info: {'Steps': 38, 'Score': 0}
# Durchgang 14, Score: 0, Info: {'Steps': 41, 'Score': 0}
# Durchgang 15, Score: 0, Info: {'Steps': 18, 'Score': 0}
# Durchgang 16, Score: 0, Info: {'Steps': 50, 'Score': 0}
# Durchgang 17, Score: 5, Info: {'Steps': 38, 'Score': 1}
# Durchgang 18, Score: 0, Info: {'Steps': 52, 'Score': 0}
# Durchgang 19, Score: 0, Info: {'Steps': 22, 'Score': 0}

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env, warn=True)
# Out:
# C:\Users\lk3\source\repos\Python_DataScience_2023_09_11\venv\lib\site-packages\stable_baselines3\common\env_checker.py:244: UserWarning: Your observation  has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(

# %%
from stable_baselines3 import PPO

# %%
env = SnakePlayer()

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57.5     |
# |    ep_rew_mean     | 0.714    |
# | time/              |          |
# |    fps             | 433      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.3        |
# |    ep_rew_mean          | 0.667       |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.020251282 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.871      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0169      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0385     |
# |    value_loss           | 0.373       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.6        |
# |    ep_rew_mean          | 0.65        |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 3           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.019467255 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.515      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.102      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0518     |
# |    value_loss           | 0.237       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.8        |
# |    ep_rew_mean          | 0.75        |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015942898 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.00942    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.184       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0426     |
# |    value_loss           | 0.415       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.6       |
# |    ep_rew_mean          | 0.65       |
# | time/                   |            |
# |    fps                  | 250        |
# |    iterations           | 5          |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.02006222 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | -0.351     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0396     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0509    |
# |    value_loss           | 0.275      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.6        |
# |    ep_rew_mean          | 0.45        |
# | time/                   |             |
# |    fps                  | 247         |
# |    iterations           | 6           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020372692 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.299      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0416     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0536     |
# |    value_loss           | 0.218       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.8        |
# |    ep_rew_mean          | 0.45        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 7           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.022258978 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.806      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0757      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.058      |
# |    value_loss           | 0.174       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.3        |
# |    ep_rew_mean          | 0.5         |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 8           |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.023108939 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.272      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00372     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.052      |
# |    value_loss           | 0.207       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.6        |
# |    ep_rew_mean          | 0.6         |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 9           |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018837897 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | -0.0697     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.213       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0448     |
# |    value_loss           | 0.455       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.6        |
# |    ep_rew_mean          | 0.7         |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 10          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.024285298 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | -0.344      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0172     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0538     |
# |    value_loss           | 0.248       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 67.2       |
# |    ep_rew_mean          | 0.75       |
# | time/                   |            |
# |    fps                  | 215        |
# |    iterations           | 11         |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02449346 |
# |    clip_fraction        | 0.262      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | -0.198     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.177      |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0521    |
# |    value_loss           | 0.338      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 72.1        |
# |    ep_rew_mean          | 0.8         |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 12          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.025529774 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.161      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.044      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.052      |
# |    value_loss           | 0.378       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.6        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 13          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.025163025 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.153      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.23        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0494     |
# |    value_loss           | 0.427       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.8        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 14          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.025197687 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.664      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.15        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0563     |
# |    value_loss           | 0.348       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.1        |
# |    ep_rew_mean          | 0.8         |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 15          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.029983774 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.467      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0373     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0556     |
# |    value_loss           | 0.315       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.4        |
# |    ep_rew_mean          | 0.75        |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 16          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.032620773 |
# |    clip_fraction        | 0.329       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | -0.552      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.056      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0614     |
# |    value_loss           | 0.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.2        |
# |    ep_rew_mean          | 0.65        |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 17          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.028892701 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | -0.226      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.024       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0443     |
# |    value_loss           | 0.248       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 87.5       |
# |    ep_rew_mean          | 0.7        |
# | time/                   |            |
# |    fps                  | 211        |
# |    iterations           | 18         |
# |    time_elapsed         | 174        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.03408447 |
# |    clip_fraction        | 0.301      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.907     |
# |    explained_variance   | -0.169     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0531     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0495    |
# |    value_loss           | 0.217      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85.8       |
# |    ep_rew_mean          | 0.95       |
# | time/                   |            |
# |    fps                  | 212        |
# |    iterations           | 19         |
# |    time_elapsed         | 182        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.02724376 |
# |    clip_fraction        | 0.254      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.866     |
# |    explained_variance   | -0.0849    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0774     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.038     |
# |    value_loss           | 0.479      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.1        |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 20          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.029786007 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.874      |
# |    explained_variance   | -0.127      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0787      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0455     |
# |    value_loss           | 0.557       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 101       |
# |    ep_rew_mean          | 1.05      |
# | time/                   |           |
# |    fps                  | 214       |
# |    iterations           | 21        |
# |    time_elapsed         | 200       |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0284625 |
# |    clip_fraction        | 0.275     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.834    |
# |    explained_variance   | -0.11     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.146     |
# |    n_updates            | 200       |
# |    policy_gradient_loss | -0.0456   |
# |    value_loss           | 0.277     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | 1.15        |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 22          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.031659063 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.83       |
# |    explained_variance   | -0.312      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0136     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0499     |
# |    value_loss           | 0.0856      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | 1.25        |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 23          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.030755576 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.809      |
# |    explained_variance   | -0.0946     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00523     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.043      |
# |    value_loss           | 0.372       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | 1.3         |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 24          |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.034881845 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | -0.353      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.238       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0482     |
# |    value_loss           | 0.314       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 131         |
# |    ep_rew_mean          | 1.2         |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 25          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.029446235 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | -0.274      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0412     |
# |    value_loss           | 0.267       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 147        |
# |    ep_rew_mean          | 1.25       |
# | time/                   |            |
# |    fps                  | 208        |
# |    iterations           | 26         |
# |    time_elapsed         | 254        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.03342507 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.757     |
# |    explained_variance   | -0.995     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0545    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0417    |
# |    value_loss           | 0.195      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | 1.2         |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 27          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.031161312 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | -0.433      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0326     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0415     |
# |    value_loss           | 0.155       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 158        |
# |    ep_rew_mean          | 1.15       |
# | time/                   |            |
# |    fps                  | 207        |
# |    iterations           | 28         |
# |    time_elapsed         | 276        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.03388648 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.744     |
# |    explained_variance   | -0.0102    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.131      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.043     |
# |    value_loss           | 0.383      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 152        |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 207        |
# |    iterations           | 29         |
# |    time_elapsed         | 286        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.03452716 |
# |    clip_fraction        | 0.283      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.712     |
# |    explained_variance   | -4.4       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0322    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0521    |
# |    value_loss           | 0.039      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 164         |
# |    ep_rew_mean          | 0.9         |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 30          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.042515524 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.713      |
# |    explained_variance   | -0.162      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0906      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 0.0939      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 161         |
# |    ep_rew_mean          | 0.85        |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 31          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.035661653 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.758      |
# |    explained_variance   | -2.05       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0492     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.051      |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 164         |
# |    ep_rew_mean          | 0.85        |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 32          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.028516058 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | -0.0177     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0969      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 0.183       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | 0.85        |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 33          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.030343115 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.722      |
# |    explained_variance   | -0.264      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00348    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0408     |
# |    value_loss           | 0.219       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 34          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.031047259 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.699      |
# |    explained_variance   | -0.173      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0383     |
# |    value_loss           | 0.356       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 1.1         |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 35          |
# |    time_elapsed         | 343         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.028000092 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.699      |
# |    explained_variance   | -0.171      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.29        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0438     |
# |    value_loss           | 0.548       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 143        |
# |    ep_rew_mean          | 1.15       |
# | time/                   |            |
# |    fps                  | 208        |
# |    iterations           | 36         |
# |    time_elapsed         | 354        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.03498807 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.707     |
# |    explained_variance   | -0.77      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0561    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0443    |
# |    value_loss           | 0.238      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 148        |
# |    ep_rew_mean          | 1.3        |
# | time/                   |            |
# |    fps                  | 198        |
# |    iterations           | 37         |
# |    time_elapsed         | 382        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.03562224 |
# |    clip_fraction        | 0.259      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.671     |
# |    explained_variance   | -0.114     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0298    |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0396    |
# |    value_loss           | 0.155      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | 1.45        |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 38          |
# |    time_elapsed         | 402         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.034451433 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.659      |
# |    explained_variance   | -0.195      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0281      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0378     |
# |    value_loss           | 0.251       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 167         |
# |    ep_rew_mean          | 1.45        |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 39          |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.033659708 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.651      |
# |    explained_variance   | -0.177      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0124      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0408     |
# |    value_loss           | 0.348       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | 1.5         |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 40          |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.039473526 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.615      |
# |    explained_variance   | -3.37       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0657     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0477     |
# |    value_loss           | 0.0517      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 1.25        |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 41          |
# |    time_elapsed         | 430         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.040371917 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.601      |
# |    explained_variance   | -0.241      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0695      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0445     |
# |    value_loss           | 0.0857      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 1.15        |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 42          |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.038342062 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.627      |
# |    explained_variance   | -2.02       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0604     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0456     |
# |    value_loss           | 0.0173      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 201         |
# |    ep_rew_mean          | 1.2         |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 43          |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.038595412 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | -0.802      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0428     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0446     |
# |    value_loss           | 0.0124      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 211         |
# |    ep_rew_mean          | 1.1         |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 44          |
# |    time_elapsed         | 462         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.037441872 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.601      |
# |    explained_variance   | 0.0517      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0141      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0303     |
# |    value_loss           | 0.253       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 1.15        |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 45          |
# |    time_elapsed         | 472         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.039320864 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | -0.528      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0381     |
# |    value_loss           | 0.224       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 227         |
# |    ep_rew_mean          | 1.1         |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 46          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.036772445 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.553      |
# |    explained_variance   | -0.257      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0079      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0358     |
# |    value_loss           | 0.194       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 236       |
# |    ep_rew_mean          | 1.05      |
# | time/                   |           |
# |    fps                  | 193       |
# |    iterations           | 47        |
# |    time_elapsed         | 498       |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.0347161 |
# |    clip_fraction        | 0.228     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.543    |
# |    explained_variance   | -0.313    |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0523   |
# |    n_updates            | 460       |
# |    policy_gradient_loss | -0.0359   |
# |    value_loss           | 0.17      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 250        |
# |    ep_rew_mean          | 1.2        |
# | time/                   |            |
# |    fps                  | 193        |
# |    iterations           | 48         |
# |    time_elapsed         | 508        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.03430764 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.551     |
# |    explained_variance   | -2.89      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0357    |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0374    |
# |    value_loss           | 0.0199     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | 1.15        |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 49          |
# |    time_elapsed         | 518         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.034574524 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 0.0519      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0243     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0312     |
# |    value_loss           | 0.315       |
# -----------------------------------------

# %%
model.save("Models/Snake")

# %%
env = SnakePlayer()

# %%
model.load("Models/SnakeDemo", env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
durchgaenge = 10  # Anzahl Durchgänge der Umgebung
for d in range(durchgaenge):  # Teste die Umgebung X mal
    observation = env.reset()  # Setzt die Umgebung zurück und gibt einige Werte zurück
    done = False  # Umgebungen können Zeitlimitiert sein (hier 200ms)
    score = 0
    
    while not done:
        env.render()  # Zeichne die Umgebung (falls möglich)
        if len(observation) == 2:
            observation = observation[0]
        action, _ = model.predict(observation)  # 2 Parameter: Action, next State (in wiederkehrenden Modellen)
        observation, reward, done, term, info = env.step(action)
        score += reward
    print(f"Durchgang: {d}, Score: {score}, Steps: {info}")
env.close()
# Out:
# Durchgang: 0, Score: 0, Steps: {'Steps': 107, 'Score': 0}
# Durchgang: 1, Score: 0, Steps: {'Steps': 46, 'Score': 0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 8
#       5 score = 0
#       7 while not done:
# ----> 8     env.render()  # Zeichne die Umgebung (falls möglich)
#       9     if len(observation) == 2:
#      10         observation = observation[0]
#
# Cell In[6], line 36, in SnakePlayer.render(self)
#      34 def render(self):
#      35     self.game.setupUI()
# ---> 36     self.game.window.update()
#      37     pass
#
# File ~\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py:1343, in Misc.update(self)
#    1341 def update(self):
#    1342     """Enter event loop until all pending events have been processed by Tcl."""
# -> 1343     self.tk.call('update')
#
# KeyboardInterrupt:
