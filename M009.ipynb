# %% [markdown]
# ## Reinforcement Learning

# %% [markdown]
# Beim Reinforcement Learning werden im Gegensatz zu klassischen Machine Learning Methoden keine vorgegebenen Daten verwendet, sondern das Datenset wird während des Prozess generiert und direkt verarbeitet.

# %% [markdown]
# Zum RL gibt es mehrere Begriffe:
#
# - Umgebung (Environment)
#     - Erzeugt die Trainingsdaten indem sie das unterliegende Programm kontinuierlich ausliest und Inputs an das Programm weiter gibt
#     - Effektiv das Programm, dass trainiert werden soll
#
# - Prozess
#     - Schleife die das Programm in Schritten ausführt
#     - Inputs vom Agenten nehmen und weitergeben
#
# - Agent
#     - Kennt den Lernprozess
#     - Agent generiert Inputs (Actions) und gibt diese an den Prozess weiter
#     - Daraus lernt der Agent positive und negative Actions anhand der generierten Daten
#     - Beim Lernen bekommt der Agent für positive Actions Punkte als Belohnung, die der Machine Learning Algorithmus als "Fortschritt" ansieht

# %% [markdown]
# Zudem benötigen wir noch einige Packages
# - Gym(nasium)
#     - Stellt Environment, Agent, Space, ... zur Verfügung
#
# - Stable Baselines 3
#     - Stellt einige nützliche Klassen und Funktion zum RL zur Verfügung

# %%
import gymnasium as gym

# %% [markdown]
# ## Vordefinierte Umgebungen
#
# Es gibt einige von OpenAI vorgegebene Testumgebungen dir wir zum testen verschiedener Methoden verwenden können
#
# Eine davon ist die "CartPole" Umgebung
#
# Bei dieser geht es darum, ein Kart mit einer Stange möglichst gerade zu halten durch Links- und Rechtsbewegungen
#
# https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
env = gym.make("CartPole-v1", render_mode="human")

# %% [markdown]
# ## Inhalte der Umgebung
#
# Es gibt einige Begriffe die mit der Umgebung zusammenhängen
#
# Spaces
# - Action Space: Beschreibt die Aktionen die der Agent ausführen kann
# - Observation Space: Liste der Daten die beim Ausführen von Actions in der Umgebung erzeugt werden -> Training mihilfe dieser Daten
# - Discrete, Box, Tuple, Dict, ...
#
# Funktionen der Umgebung
# - __init__: Setzt die Umgebung auf (Setup)
# - reset(): Setzt die Umgebung auf den Start zurück
# - render(): Zeichne die Umgebung (falls möglich)
# - step(): Führe die Action aus die vom Agenten ausgewählt wird
# - close(): Beende die Umgebung

# %%
durchgänge = 5  # Anzahl der Durchgänge
for i in range(durchgänge):  # Teste die Umgebung X mal
    state = env.reset()  # Setze die Umgebung für den nächsten Durchlauf zurück
    done = False  # Brich den Prozess ab, wenn z.B. die Zeit abläuft
    score = 0

    while not done:
        env.render()  # Zeichne die Umgebung
        action = env.action_space.sample()  # Nimmt ein Random Element aus dem Action Space (Links oder Rechts)
        state, reward, done, term, info = env.step(action)  # state: Observation Space, reward: Belohnung, done: Fertig Ja/Nein, term: Termination (vorzeitiges Beenden), info: Extra Infos
        score += reward
    print(f"Durchgang {i}, Score: {score}")
env.close()
# Out:
# Durchgang 0, Score: 24.0
# Durchgang 1, Score: 18.0
# Durchgang 2, Score: 18.0
# Durchgang 3, Score: 23.0
# Durchgang 4, Score: 15.0

# %%
env.action_space.sample()  # Discrete(X): Aufsteigende Liste von 0 bis X
# Out:
# 0

# %%
env.observation_space.sample()  # [Position, Geschwindigkeit, Winkel der Stange, L-R Geschwindigkeit der Stange]
# Out:
# array([-2.7179307e-01,  2.9223054e+38, -1.7964810e-01, -1.0291461e+38],
#       dtype=float32)

# %% [markdown]
# ## RL Model trainieren

# %% [markdown]
# Für ein RL Modell benötigen wir einen Algorithmus
# - PPO: Proximal Policy Optimation
# - https://stable-baselines.readthedocs.io/en/master/guide/algos.html
#
# DummyVecEnv (optional)
# - Simulation mehrerer Agenten gleichzeitig
# - Sehr nützlich um Zeit zu sparen
#
# Policy:
# - Bestimmt wie der Algorithmus lernt
# - https://stable-baselines.readthedocs.io/en/master/modules/policies.html

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
env = gym.make("CartPole-v1")
env = DummyVecEnv([lambda: env])
model = PPO("MlpPolicy", env, verbose=1)  # MLP: Multilayer Perceptron -> effektiv Dense Layer
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 949  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008697905 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00258    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.69        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 48.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010962971 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0814      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 33          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 449          |
# |    iterations           | 4            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0073244227 |
# |    clip_fraction        | 0.0638       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.636       |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25           |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0145      |
# |    value_loss           | 53.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 5            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0071908897 |
# |    clip_fraction        | 0.0639       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.608       |
# |    explained_variance   | 0.333        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.4         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0154      |
# |    value_loss           | 56.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 6            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0085644275 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.591       |
# |    explained_variance   | 0.575        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.1         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0158      |
# |    value_loss           | 55.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 7           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015101153 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.42        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 43.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 8           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.003954344 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.29        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00366    |
# |    value_loss           | 30.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 403          |
# |    iterations           | 9            |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0026057903 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.571       |
# |    explained_variance   | 0.717        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.1         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00512     |
# |    value_loss           | 42.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 10          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.003819746 |
# |    clip_fraction        | 0.0174      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.12        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00247    |
# |    value_loss           | 13.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 11          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005719305 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.588      |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.86        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00699    |
# |    value_loss           | 9.99        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 392          |
# |    iterations           | 12           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0072450605 |
# |    clip_fraction        | 0.0241       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.579       |
# |    explained_variance   | 0.459        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.4         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00377     |
# |    value_loss           | 86.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 392         |
# |    iterations           | 13          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.001564618 |
# |    clip_fraction        | 0.0106      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.09        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00293    |
# |    value_loss           | 24.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 14          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008357748 |
# |    clip_fraction        | 0.0538      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.13        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00742    |
# |    value_loss           | 9.22        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 15          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007538313 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.555      |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 29.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 16          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006488459 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.552      |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.68        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00782    |
# |    value_loss           | 21          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 17          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.004868779 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.527      |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.08        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00393    |
# |    value_loss           | 28.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 18          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006810067 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.499      |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0907      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 0.633       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 389          |
# |    iterations           | 19           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0070779026 |
# |    clip_fraction        | 0.0806       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.495       |
# |    explained_variance   | 0.0585       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.047        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00534     |
# |    value_loss           | 0.328        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 20          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.003482803 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | -0.085      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0219      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.000623   |
# |    value_loss           | 0.22        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 21           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0020361375 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | 0.0216       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0212       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00047     |
# |    value_loss           | 0.134        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 389          |
# |    iterations           | 22           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0030853269 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.466       |
# |    explained_variance   | -0.0094      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0022       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000897    |
# |    value_loss           | 0.0864       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 389          |
# |    iterations           | 23           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0041515967 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.463       |
# |    explained_variance   | -0.026       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0071       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000109    |
# |    value_loss           | 0.0531       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 389          |
# |    iterations           | 24           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0055114273 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | 0.0339       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00817     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 0.0352       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 25           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0037180472 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.472       |
# |    explained_variance   | -0.0301      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0117       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.000331     |
# |    value_loss           | 0.0226       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 26          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006069946 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.452      |
# |    explained_variance   | 0.0947      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00218     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00411    |
# |    value_loss           | 0.0137      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 27           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0025629036 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.441       |
# |    explained_variance   | 0.00159      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00461      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 0.00947      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 28          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.002477876 |
# |    clip_fraction        | 0.0138      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.44       |
# |    explained_variance   | -0.0348     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00127     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.000115    |
# |    value_loss           | 0.00608     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 29           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0029095258 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.44        |
# |    explained_variance   | -0.0398      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00726      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000439    |
# |    value_loss           | 0.00422      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 30          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004438586 |
# |    clip_fraction        | 0.038       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.441      |
# |    explained_variance   | -0.0666     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000597   |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 0.00292     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 31           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0027899253 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.421       |
# |    explained_variance   | -0.0282      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000802    |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00378     |
# |    value_loss           | 0.00194      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 32          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.006146821 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | -0.0666     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00419    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.000565   |
# |    value_loss           | 0.00127     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 33          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004742576 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.433      |
# |    explained_variance   | -0.00197    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0183     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00434    |
# |    value_loss           | 0.000936    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 34           |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0013230079 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.439       |
# |    explained_variance   | -0.104       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00291      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00014     |
# |    value_loss           | 0.000615     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 35           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0048147533 |
# |    clip_fraction        | 0.0705       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.426       |
# |    explained_variance   | -0.167       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00681     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 0.000425     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 36          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.002163249 |
# |    clip_fraction        | 0.024       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.424      |
# |    explained_variance   | -0.164      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.000391   |
# |    value_loss           | 0.000347    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 37          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004071487 |
# |    clip_fraction        | 0.0858      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.428      |
# |    explained_variance   | -0.209      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -4.77e-05   |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 0.000275    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 38           |
# |    time_elapsed         | 201          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0069156988 |
# |    clip_fraction        | 0.0711       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.424       |
# |    explained_variance   | -0.143       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0104      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 0.000173     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 39           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0051371767 |
# |    clip_fraction        | 0.063        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.417       |
# |    explained_variance   | -0.241       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00959      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 0.000119     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 40           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0024152503 |
# |    clip_fraction        | 0.0489       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.414       |
# |    explained_variance   | -0.0259      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00293     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 7.45e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 41           |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0020964108 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.395       |
# |    explained_variance   | -0.23        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00322      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000508    |
# |    value_loss           | 6.07e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 42           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0033211256 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.391       |
# |    explained_variance   | -0.351       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0143      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 4.51e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 43           |
# |    time_elapsed         | 227          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0025152187 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.365       |
# |    explained_variance   | -0.657       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00128     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 3.45e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 44           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0014798318 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.348       |
# |    explained_variance   | -0.493       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00635      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00084     |
# |    value_loss           | 2.35e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 45          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.004254737 |
# |    clip_fraction        | 0.0201      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.338      |
# |    explained_variance   | -0.708      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000597    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.000451   |
# |    value_loss           | 1.85e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 46           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0011825974 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.316       |
# |    explained_variance   | -0.395       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00421      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 1.5e-05      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 47          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.001907811 |
# |    clip_fraction        | 0.0148      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.293      |
# |    explained_variance   | -0.713      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00124     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.000705   |
# |    value_loss           | 8.5e-06     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 48           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0044185044 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.298       |
# |    explained_variance   | -0.964       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0066       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000311    |
# |    value_loss           | 8.18e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 49           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0054807854 |
# |    clip_fraction        | 0.0838       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.294       |
# |    explained_variance   | -1.82        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0195      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00597     |
# |    value_loss           | 6.99e-06     |
# ------------------------------------------

# %% [markdown]
# ## Modell speichern
#
# Wird benötigt, um das Modell auf die neue Umgebung anzuwenden

# %%
model.save("Models/CartPole")

# %% [markdown]
# ## Modell evaluieren

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
evaluate_policy(model, env, n_eval_episodes=10)  # Durchschnittlicher Score, Standardabweichung
# Out:
# (500.0, 0.0)

# %%
env.close()

# %% [markdown]
# ## Model testen

# %%
import numpy as np

# %%
env = gym.make("CartPole-v1")

# %%
model = PPO.load("Models/CartPoleModel", env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
durchgänge = 5  # Anzahl der Durchgänge
for i in range(durchgänge):  # Teste die Umgebung X mal
    observation = env.reset()  # Setze die Umgebung für den nächsten Durchlauf zurück
    done = False  # Brich den Prozess ab, wenn z.B. die Zeit abläuft
    score = 0
    observation = observation[0].reshape(1, 4)

    while not done:
        env.render()  # Zeichne die Umgebung
        action, _ = model.predict(observation)  # Nimmt den State nach Reset
        if action.ndim == 1:
            action = action[0]
        observation, reward, done, term, info = env.step(action)  # state: Observation Space, reward: Belohnung, done: Fertig Ja/Nein, term: Termination (vorzeitiges Beenden), info: Extra Infos
        score += reward
    print(f"Durchgang {i}, Score: {score}")
env.close()
# Out:
# Durchgang 0, Score: 469.0
# Durchgang 1, Score: 964.0
# Durchgang 2, Score: 488.0
# Durchgang 3, Score: 770.0
# Durchgang 4, Score: 587.0
